# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load the data (replace 'wine_quality.csv' with your file path)
data = pd.read_csv('/home/bhoomi/Documents/sem5/ML_lab/WineQT.csv')

# Convert quality attribute
data['quality'] = data['quality'].apply(lambda x: 1 if x > 6 else 0)

# Separate features and quality
features = data.drop('quality', axis=1)
quality = data['quality']

# Min-max scaling
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(features)

# Reassemble the data
scaled_data = pd.DataFrame(scaled_features, columns=features.columns)
scaled_data['quality'] = quality

# Save the processed data
scaled_data.to_csv('processed_wine_quality.csv', index=False)

# %%
scaled_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1138       0.150442          0.267123         0.13        0.095890   0.106845
# 1139       0.194690          0.342466         0.08        0.068493   0.093489
# 1140       0.141593          0.328767         0.08        0.075342   0.130217
# 1141       0.115044          0.294521         0.10        0.089041   0.083472
# 1142       0.115044          0.359589         0.12        0.075342   0.105175
#
# ...
